# %% [markdown]
# # Memory Based Model

# %% [markdown]
# this calculates nearest users

# %%
from surprise import SVD
from surprise import Dataset
from surprise.model_selection import cross_validate
from surprise import accuracy
from surprise.model_selection import train_test_split
from surprise import Reader
from surprise.model_selection import KFold

from surprise.prediction_algorithms import knns
from surprise.similarities import cosine, msd, pearson

import pandas as pd

from surprise.model_selection import GridSearchCV

import bgg_data_func

import bgg_model_func

from game_name_converter import NameConverter

# %%
file_path = './data_input/games_40_summary.csv'

reader = Reader(line_format='user item rating', sep=',', rating_scale = (1,10))

data = Dataset.load_from_file(file_path, reader=reader)

# %%
trainset, testset = train_test_split(data, test_size=0.2)

# %%
print('Number of users: ', trainset.n_users, '\n')
print('Number of items: ', trainset.n_items, '\n')
# Out:
# Number of users:  179856
#
# Number of items:  40

# %%
trainsetfull = data.build_full_trainset()
print('Number of users: ', trainsetfull.n_users, '\n')
print('Number of items: ', trainsetfull.n_items, '\n')
# Out:
# Number of users:  192606
#
# Number of items:  40

# %%
trainset_iids = list(trainset.all_items())
iid_converter = lambda x: trainset.to_raw_iid(x)
trainset_raw_iids = list(map(iid_converter, trainset_iids))

# %%
name_converter = NameConverter('games_master_list.csv')
name_converter.get_game_name_from_id(84876)
# Out:
# 'The Castles of Burgundy'

# %% [markdown]
# ## Similarity

# %%
sim_cos = {'name':'cosine', 'user_based':False}
basic_cos = knns.KNNBasic(sim_options=sim_cos)
basic_cos.fit(trainset)
predictions = basic_cos.test(testset)
print(accuracy.rmse(predictions))
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3831
# 1.383147354364512

# %%
df = bgg_model_func.return_top_similar_dataframe(basic_cos.sim, trainset_raw_iids, 3)
for column in df.columns:
    df[column] = df[column].map(name_converter.get_game_name_from_id)
df.sort_values(['game'], inplace = True, axis = 0)
df
# Out:
#                                              game  \
# 2                                  7 Wonders Duel
# 24                               A Feast for Odin
# 7                                        Agricola
# 29                   Arkham Horror: The Card Game
# 30                                     Blood Rage
# 6                               Brass: Birmingham
# 3                               Brass: Lancashire
# 13                      Caverna: The Cave Farmers
# 31                                      Concordia
# 28                             Food Chain Magnate
# 0                                    Gaia Project
# 18                                     Gloomhaven
# 33                            Great Western Trail
# 21                         Kingdom Death: Monster
# 23                         Mage Knight Board Game
# 14            Mansions of Madness: Second Edition
# 22                              Mechs vs. Minions
# 39                                        Nemesis
# 36                                        Orléans
# 9                       Pandemic Legacy: Season 1
# 35                      Pandemic Legacy: Season 2
# 16                                     Power Grid
# 8                                     Puerto Rico
# 25                                           Root
# 11                                         Scythe
# 26                                  Spirit Island
# 4                     Star Wars: Imperial Assault
# 37                           Star Wars: Rebellion
# 17                                  Terra Mystica
# 19                              Terraforming Mars
# 12                              The 7th Continent
# 5                         The Castles of Burgundy
# 20  Through the Ages: A New Story of Civilization
# 1       Through the Ages: A Story of Civilization
# 34             Twilight Imperium (Fourth Edition)
# 10                              Twilight Struggle
# 15                   Tzolk'in: The Mayan Calendar
# 27                  Viticulture Essential Edition
# 38               War of the Ring (Second Edition)
# 32                                       Wingspan
#
#                                         similar_1  \
# 2                                         Orléans
# 24                      Caverna: The Cave Farmers
# 7                       Caverna: The Cave Farmers
# 29            Mansions of Madness: Second Edition
# 30                                 7 Wonders Duel
# 6                               Brass: Lancashire
# 3                               Brass: Birmingham
# 13                               A Feast for Odin
# 31                                        Orléans
# 28                              Brass: Birmingham
# 0                                   Terra Mystica
# 18                              Mechs vs. Minions
# 33                                        Orléans
# 21                              The 7th Continent
# 23  Through the Ages: A New Story of Civilization
# 14                   Arkham Horror: The Card Game
# 22                                     Gloomhaven
# 39                           Star Wars: Rebellion
# 36                                      Concordia
# 9                       Pandemic Legacy: Season 2
# 35                      Pandemic Legacy: Season 1
# 16                                      Concordia
# 8                                       Concordia
# 25                                  Spirit Island
# 11                  Viticulture Essential Edition
# 26                                           Root
# 4                            Star Wars: Rebellion
# 37                    Star Wars: Imperial Assault
# 17                                   Gaia Project
# 19                                       Wingspan
# 12                                     Gloomhaven
# 5                                         Orléans
# 20      Through the Ages: A Story of Civilization
# 1   Through the Ages: A New Story of Civilization
# 34                           Star Wars: Rebellion
# 10                           Star Wars: Rebellion
# 15                                        Orléans
# 27                                        Orléans
# 38                           Star Wars: Rebellion
# 32                  Viticulture Essential Edition
#
#                                         similar_2  \
# 2                         The Castles of Burgundy
# 24                                        Orléans
# 7                                     Puerto Rico
# 29                    Star Wars: Imperial Assault
# 30                                         Scythe
# 6                             Great Western Trail
# 3                                       Concordia
# 13                                        Orléans
# 31                            Great Western Trail
# 28                              Brass: Lancashire
# 0                             Great Western Trail
# 18                                  Spirit Island
# 33                                      Concordia
# 21                   Arkham Horror: The Card Game
# 23                                  Spirit Island
# 14                    Star Wars: Imperial Assault
# 22                                       Wingspan
# 39             Twilight Imperium (Fourth Edition)
# 36                  Viticulture Essential Edition
# 9                                  7 Wonders Duel
# 35                                 7 Wonders Duel
# 16                                    Puerto Rico
# 8                         The Castles of Burgundy
# 25                                 7 Wonders Duel
# 11                                       Wingspan
# 26                                     Gloomhaven
# 4             Mansions of Madness: Second Edition
# 37               War of the Ring (Second Edition)
# 17                   Tzolk'in: The Mayan Calendar
# 19                                 7 Wonders Duel
# 12                   Arkham Horror: The Card Game
# 5                                       Concordia
# 20                                   Gaia Project
# 1                               Brass: Lancashire
# 34                                        Nemesis
# 10  Through the Ages: A New Story of Civilization
# 15                        The Castles of Burgundy
# 27                                       Wingspan
# 38                                           Root
# 32                                        Orléans
#
#                               similar_3
# 2         Viticulture Essential Edition
# 24                  Great Western Trail
# 7          Tzolk'in: The Mayan Calendar
# 29                 Star Wars: Rebellion
# 30        Viticulture Essential Edition
# 6                             Concordia
# 3                   Great Western Trail
# 13                  Great Western Trail
# 31              The Castles of Burgundy
# 28                  Great Western Trail
# 0                     Brass: Birmingham
# 18                    The 7th Continent
# 33                    Brass: Birmingham
# 21                           Gloomhaven
# 23                         Gaia Project
# 14                 Star Wars: Rebellion
# 22        Viticulture Essential Edition
# 39  Mansions of Madness: Second Edition
# 36                  Great Western Trail
# 9                              Wingspan
# 35                             Wingspan
# 16                    Brass: Birmingham
# 8                               Orléans
# 25                    Brass: Birmingham
# 11                              Orléans
# 26                         Gaia Project
# 4                     Mechs vs. Minions
# 37   Twilight Imperium (Fourth Edition)
# 17                  Great Western Trail
# 19        Viticulture Essential Edition
# 12                    Mechs vs. Minions
# 5                        7 Wonders Duel
# 20            Caverna: The Cave Farmers
# 1                   Great Western Trail
# 34          Star Wars: Imperial Assault
# 10                       7 Wonders Duel
# 15                            Concordia
# 27                               Scythe
# 38                    Twilight Struggle
# 32                       7 Wonders Duel

# %%
sim_pearson = {'name':'pearson', 'user_based':False}
basic_pearson = knns.KNNBasic(sim_options=sim_pearson)
basic_pearson.fit(trainset)
predictions = basic_pearson.test(testset)
print(accuracy.rmse(predictions))
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3672
# 1.3672169234920741

# %%
df = bgg_model_func.return_top_similar_dataframe(basic_pearson.sim, trainset_raw_iids, 3)
for column in df.columns:
    df[column] = df[column].map(name_converter.get_game_name_from_id)
df.sort_values(['game'], inplace = True)
df
# Out:
#                                              game  \
# 2                                  7 Wonders Duel
# 24                               A Feast for Odin
# 7                                        Agricola
# 29                   Arkham Horror: The Card Game
# 30                                     Blood Rage
# 6                               Brass: Birmingham
# 3                               Brass: Lancashire
# 13                      Caverna: The Cave Farmers
# 31                                      Concordia
# 28                             Food Chain Magnate
# 0                                    Gaia Project
# 18                                     Gloomhaven
# 33                            Great Western Trail
# 21                         Kingdom Death: Monster
# 23                         Mage Knight Board Game
# 14            Mansions of Madness: Second Edition
# 22                              Mechs vs. Minions
# 39                                        Nemesis
# 36                                        Orléans
# 9                       Pandemic Legacy: Season 1
# 35                      Pandemic Legacy: Season 2
# 16                                     Power Grid
# 8                                     Puerto Rico
# 25                                           Root
# 11                                         Scythe
# 26                                  Spirit Island
# 4                     Star Wars: Imperial Assault
# 37                           Star Wars: Rebellion
# 17                                  Terra Mystica
# 19                              Terraforming Mars
# 12                              The 7th Continent
# 5                         The Castles of Burgundy
# 20  Through the Ages: A New Story of Civilization
# 1       Through the Ages: A Story of Civilization
# 34             Twilight Imperium (Fourth Edition)
# 10                              Twilight Struggle
# 15                   Tzolk'in: The Mayan Calendar
# 27                  Viticulture Essential Edition
# 38               War of the Ring (Second Edition)
# 32                                       Wingspan
#
#                                         similar_1  \
# 2                       Caverna: The Cave Farmers
# 24                      Caverna: The Cave Farmers
# 7                       Caverna: The Cave Farmers
# 29            Mansions of Madness: Second Edition
# 30                                         Scythe
# 6                               Brass: Lancashire
# 3                               Brass: Birmingham
# 13                               A Feast for Odin
# 31                                        Orléans
# 28                         Kingdom Death: Monster
# 0                                   Terra Mystica
# 18                              Mechs vs. Minions
# 33                                   Gaia Project
# 21                              The 7th Continent
# 23      Through the Ages: A Story of Civilization
# 14                   Arkham Horror: The Card Game
# 22                                     Gloomhaven
# 39             Twilight Imperium (Fourth Edition)
# 36                                      Concordia
# 9                       Pandemic Legacy: Season 2
# 35                      Pandemic Legacy: Season 1
# 16                                    Puerto Rico
# 8                                        Agricola
# 25                                  Spirit Island
# 11                  Viticulture Essential Edition
# 26                                           Root
# 4                            Star Wars: Rebellion
# 37             Twilight Imperium (Fourth Edition)
# 17                                   Gaia Project
# 19                                       Wingspan
# 12                         Kingdom Death: Monster
# 5                                         Orléans
# 20      Through the Ages: A Story of Civilization
# 1   Through the Ages: A New Story of Civilization
# 34                           Star Wars: Rebellion
# 10      Through the Ages: A Story of Civilization
# 15                                  Terra Mystica
# 27                                         Scythe
# 38                           Star Wars: Rebellion
# 32                  Viticulture Essential Edition
#
#                              similar_2  \
# 2                              Orléans
# 24                             Orléans
# 7                          Puerto Rico
# 29                   The 7th Continent
# 30         Star Wars: Imperial Assault
# 6                  Great Western Trail
# 3                   Food Chain Magnate
# 13                            Agricola
# 31                 Great Western Trail
# 28                   Brass: Lancashire
# 0                  Great Western Trail
# 18                   The 7th Continent
# 33                   Brass: Birmingham
# 21  Twilight Imperium (Fourth Edition)
# 23    War of the Ring (Second Edition)
# 14         Star Wars: Imperial Assault
# 22                             Nemesis
# 39                   Mechs vs. Minions
# 36       Viticulture Essential Edition
# 9                           Gloomhaven
# 35                             Nemesis
# 16                   Brass: Lancashire
# 8                           Power Grid
# 25                             Nemesis
# 11                            Wingspan
# 26                   The 7th Continent
# 4   Twilight Imperium (Fourth Edition)
# 37         Star Wars: Imperial Assault
# 17           Caverna: The Cave Farmers
# 19       Viticulture Essential Edition
# 12  Twilight Imperium (Fourth Edition)
# 5         Tzolk'in: The Mayan Calendar
# 20              Mage Knight Board Game
# 1               Mage Knight Board Game
# 34                             Nemesis
# 10    War of the Ring (Second Edition)
# 15           Caverna: The Cave Farmers
# 27                            Wingspan
# 38                             Nemesis
# 32                              Scythe
#
#                                         similar_3
# 2                   Viticulture Essential Edition
# 24                            Great Western Trail
# 7                                   Terra Mystica
# 29                    Star Wars: Imperial Assault
# 30                           Star Wars: Rebellion
# 6                              Food Chain Magnate
# 3       Through the Ages: A Story of Civilization
# 13                                  Terra Mystica
# 31                        The Castles of Burgundy
# 28                              Brass: Birmingham
# 0                       Caverna: The Cave Farmers
# 18                      Pandemic Legacy: Season 1
# 33                               A Feast for Odin
# 21                                        Nemesis
# 23  Through the Ages: A New Story of Civilization
# 14                           Star Wars: Rebellion
# 22                    Star Wars: Imperial Assault
# 39                         Kingdom Death: Monster
# 36                               A Feast for Odin
# 9                               Mechs vs. Minions
# 35                              The 7th Continent
# 16                                       Agricola
# 8                       Caverna: The Cave Farmers
# 25               War of the Ring (Second Edition)
# 11                                     Blood Rage
# 26                                     Gloomhaven
# 4             Mansions of Madness: Second Edition
# 37               War of the Ring (Second Edition)
# 17                   Tzolk'in: The Mayan Calendar
# 19                                         Scythe
# 12                   Arkham Horror: The Card Game
# 5                             Great Western Trail
# 20                      Caverna: The Cave Farmers
# 1                          Kingdom Death: Monster
# 34                         Kingdom Death: Monster
# 10                              Brass: Lancashire
# 15                        The Castles of Burgundy
# 27                                        Orléans
# 38                         Mage Knight Board Game
# 32                                        Orléans

# %%
sim_pearson = {'name':'pearson', 'user_based':False}
knn_means = knns.KNNWithMeans(sim_options=sim_pearson)
knn_means.fit(trainset)
predictions = knn_means.test(testset)
print(accuracy.rmse(predictions))
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3468
# 1.3467983608876295

# %%
# sim: same as above, just calculation is different

# %%
sim_pearson = {'name':'pearson', 'user_based':False}
knn_baseline = knns.KNNBaseline(sim_options=sim_pearson)
knn_baseline.fit(trainset)
predictions = knn_baseline.test(testset)
print(accuracy.rmse(predictions))
# Out:
# Estimating biases using als...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.3549
# 1.3548980401686634

# %%
knn_baseline.predict()

# %% [markdown]
# # Model Based

# %% [markdown]
# this uses maxtor factorization

# %%
# We'll use the famous SVD algorithm.
algo = SVD()

# Train the algorithm on the trainset, and predict ratings for the testset
algo.fit(trainset)
predictions = algo.test(testset)

# Then compute RMSE
accuracy.rmse(predictions)
# Out:
# RMSE: 1.3697
# 1.3697325105207512

# %%
# param_grid = {'n_factors':[5, 10,20],'n_epochs': [5, 10, 20], 'lr_all': [0.002, 0.005],
#               'reg_all': [0.4, 0.6]}

param_grid = {'n_factors':[5, 10]}
gs_model = GridSearchCV(SVD,param_grid=param_grid,n_jobs = -1,joblib_verbose=5)
gs_model.fit(data)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of  10 | elapsed:  1.9min remaining:  1.2min
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  2.9min finished

# %%
gs_model.best_params
# Out:
# {'rmse': {'n_factors': 10}, 'mae': {'n_factors': 10}}

# %%
svd = SVD(n_factors=10)
svd.fit(trainset)
predictions = svd.test(testset)
print(accuracy.rmse(predictions))
# Out:
# RMSE: 3.5453
# 3.5453165741430865

# %%
param_grid = {'n_factors':[5, 10,20],'n_epochs': [5, 10, 20], 'lr_all': [0.002, 0.005],
              'reg_all': [0.4, 0.6]}

gs_model_2 = GridSearchCV(SVD,param_grid=param_grid,n_jobs = -1,joblib_verbose=5)
gs_model_2.fit(data)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# /Users/flatiron/opt/anaconda3/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed: 16.4min
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed: 39.5min
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed: 46.9min finished

# %%
gs_model_2.best_params
# Out:
# {'rmse': {'n_factors': 5, 'n_epochs': 20, 'lr_all': 0.005, 'reg_all': 0.4},
#  'mae': {'n_factors': 5, 'n_epochs': 20, 'lr_all': 0.005, 'reg_all': 0.4}}

# %%
svd2 = SVD(n_factors=5, n_epochs=20, lr_all=0.005, reg_all=0.4)
svd2.fit(trainset)
predictions = svd2.test(testset)
print(accuracy.rmse(predictions))
# Out:
# RMSE: 3.5450
# 3.545013880031576

# %% [markdown]
# to insert:
#
# gridsearch results can be analysed this way:
# results_df = pd.DataFrame.from_dict(gs.cv_results)
#
# bsl_options when creating an algorithm, can be sgd or als, if we do that, can define other variables too

# %% [markdown]
# # Examining Data

# %%
df = pd.read_csv('./data_input/games_31_summary.csv', header = None)

# %%
df.head()
# Out:
#              0       1     2
# 0      DRCrain  174430   7.0
# 1  Huligan1475  174430   7.0
# 2      Cama891  174430   9.0
# 3   ryosaeba83  174430   9.0
# 4     Creation  174430  10.0

# %%
df[2].describe()
# Out:
# count    866517.000000
# mean          8.237334
# std           1.440595
# min           1.000000
# 25%           7.500000
# 50%           8.300000
# 75%           9.000000
# max          10.000000
# Name: 2, dtype: float64
